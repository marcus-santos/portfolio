# %% [markdown]
# # Portfolio Optimization Study
#
# In this notebook we explore the data and compute the portfolio

# %% [markdown]
# #### Read processed data

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")

csv = 'processed/data.csv'
if not os.path.isfile(csv):
    # %run "./wrangle.ipynb";
    
df = pd.read_csv(csv, parse_dates=True, index_col="Data");

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### Correlations
#
# We set the starting year $ y_0 $ and the last year $ y_n $ and calculate de log returns $ ln(t_n) - ln(t_{n-1}) $

# %%
y_0, y_1 = '2011', '2021'
tickers = ['IMA-B', 'IFIX', 'IBOV', 'BDRX', 'DOLOF', 'NASDAQ', 'S&P 500', 'DJIA', 'WTICO', 'EURUSD']
data = df[y_0:y_1][tickers].copy()
data.loc[:, 'NASDAQ':] = data.loc[:, 'NASDAQ':].mul(data['DOLOF'], axis=0)
lreturns = np.log( data ) - np.log( data.shift(1) )
lreturns
# Out:
# C:\Users\Marcus Santos\.conda\envs\portfolio\lib\site-packages\pandas\core\internals\blocks.py:402: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
#                IMA-B      IFIX      IBOV      BDRX     DOLOF    NASDAQ  \
# Data
# 2011-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2011-01-04 -0.001208 -0.008577  0.005061  0.009412  0.002782 -0.001041
# 2011-01-05 -0.000932  0.006117  0.010947  0.015203  0.009438  0.017221
# 2011-01-06 -0.001144 -0.002346 -0.007242  0.007277  0.008579  0.011421
# 2011-01-07 -0.003559  0.004516 -0.007409 -0.005355  0.000237 -0.002246
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-27 -0.000321  0.006978  0.006302  0.001678  0.001042  0.014866
# 2021-12-28 -0.000163  0.008832 -0.006561 -0.001916 -0.003749 -0.009407
# 2021-12-29 -0.004236  0.007666 -0.007244  0.014067  0.003202  0.002219
# ...

# %%
sns.heatmap(lreturns.corr(), annot=True, fmt='.2f');

# %% [markdown]
# We find strong correlations between `NASDAQ`, `S&P 500` and `DJIA`
#
# Also, `EURUSD` shows correlation above `0.8` against `DOLOF`
#
# Dropping `NASDAQ`, `DJIA` and `EURUSD`

# %%
lreturns.drop(columns=['DJIA', 'NASDAQ', 'EURUSD'], inplace=True)
sns.heatmap(lreturns.corr(), annot=True, fmt='.2f');

# %% [markdown]
# ### Explore the log returns

# %% [markdown]
# #### Descriptive Statitcs

# %%
lreturns.describe()
# Out:
#              IMA-B         IFIX         IBOV         BDRX        DOLOF  \
# count  2869.000000  2869.000000  2869.000000  2869.000000  2869.000000
# mean      0.000423     0.000359     0.000141     0.000927     0.000425
# std       0.004935     0.005320     0.015562     0.013271     0.008965
# min      -0.078184    -0.141912    -0.159938    -0.303322    -0.060686
# 25%      -0.001339    -0.001407    -0.007838    -0.004464    -0.004191
# 50%       0.000428     0.000187     0.000000     0.000416     0.000000
# 75%       0.002526     0.002280     0.008418     0.006672     0.004897
# max       0.052596     0.056587     0.130228     0.275915     0.084232
#
#            S&P 500        WTICO
# count  2869.000000  2867.000000
# mean      0.000885     0.000606
# std       0.012255     0.028914
# min      -0.084093    -0.276604
# 25%      -0.005337    -0.010451
# 50%       0.000902     0.000564
# 75%       0.007155     0.011860
# max       0.087912     0.444767

# %% [markdown]
# #### Box plots

# %%
lreturns.plot.box(figsize=(15, 10));

# %% [markdown]
# It is possible to observe a lot of outliers in `WTICO`
#
# For a better view of the boxes we set $ Y $ axis to $ [-0.1, 0.1] $

# %%
lreturns.plot.box(figsize=(15, 10), ylim=(-0.1, 0.1));

# %% [markdown]
# ## Basic Markowitz

# %% [markdown]
# We use `PyPortfolioOpt`to make a basic Markowitz portfolio with the Mean-Variance Optimization

# %%
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import risk_models
from pypfopt import expected_returns
from pypfopt import plotting

# Calculate expected returns and sample covariance
mu = expected_returns.mean_historical_return(lreturns, returns_data=True)
S = risk_models.sample_cov(lreturns, returns_data=True)

# %% [markdown]
# ### Expected Returns

# %%
mu.plot.barh(figsize=(10,6));

# %% [markdown]
# ### Estimated Variance

# %%
sns.heatmap(S, annot=True, fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Optimize with Max Sharpe
#
# Full date range

# %%
ef = EfficientFrontier(mu, S)
weights = ef.max_sharpe()
ex_return, ex_vol, sharpe = ef.portfolio_performance(verbose=True)
# Out:
# Expected annual return: 12.3%
# Annual volatility: 5.5%
# Sharpe Ratio: 1.89

# %%
pd.Series(weights, name="Weights % for Max Sharpe").plot.pie(figsize=(6,6), autopct="%.2f", fontsize=14);

# %%
ef2 = EfficientFrontier(mu, S) # workaround for bug https://github.com/robertmartin8/PyPortfolioOpt/issues/373
plotting.plot_efficient_frontier(ef2);

# %% [markdown]
# ## Markowitz Portfolio 3 years for 1 year

# %%
def calc_markowitz(returns, verbose=False):
    mu = expected_returns.mean_historical_return(returns, returns_data=True)
    S = risk_models.sample_cov(returns, returns_data=True)
    ef = EfficientFrontier(mu, S)
    weights = ef.max_sharpe()
    r, v, s = ef.portfolio_performance(verbose=verbose)
    return dict(expected_return=r, expected_volatility=v, sharpe=s, weights=weights)


def calc_future_perf(returns, weights, year_begin, year_last=None):
    year_last = year_begin if not year_last else year_last
    future = returns[str(year_begin):str(year_last)].add(1).cumprod(axis=0).sub(1);
    weighted_future = future * pd.Series(weights)
    total = weighted_future.sum(axis=1)
    r = total.iloc[-1]
    v = total.std()
    high, low = total.max(), total.min()
    return dict(real_return = r, 
                real_volatility = v, 
                real_sharpe = (r - 0.02) /  v, 
                real_high=high, real_low=low)

    
def calc_markowitz_year(returns, n_years = 3, n_years_test = 1):
    years = returns.index.year.unique()
    out = []
    for year in years:
        year_last = year + n_years - 1
        year_test = year_last + n_years_test
        if year_test not in years:
            break;
        data = calc_markowitz(returns[str(year):str(year_last)], verbose=False)
        w = data['weights']
        del data['weights']
        data = dict(year_begin=year, year_last=year_last, year_test=year_test, **data)
        fdata = calc_future_perf(returns, w, year_begin=year_test, year_last=year_test)
        
        data = dict(**data, **fdata, **w)
        out.append(data)

    return out

data = calc_markowitz_year(lreturns, n_years = 2, n_years_test = 1)
results = pd.DataFrame(data)
results
# Out:
#    year_begin  year_last  year_test  expected_return  expected_volatility  \
# 0        2011       2012       2013         0.209855             0.038946
# 1        2012       2013       2014         0.205864             0.060619
# 2        2013       2014       2015         0.246063             0.083126
# 3        2014       2015       2016         0.208746             0.065455
# 4        2015       2016       2017         0.157859             0.044048
# 5        2016       2017       2018         0.203122             0.045654
# 6        2017       2018       2019         0.118320             0.033880
# 7        2018       2019       2020         0.172356             0.029524
# 8        2019       2020       2021         0.184077             0.076314
#
#      sharpe  real_return  real_volatility  real_sharpe  real_high  real_low  \
# 0  4.874806    -0.083433         0.037107    -2.787414   0.016518 -0.089874
# ...

# %%
results.set_index('year_test').loc[: , ['sharpe', 'real_sharpe']].plot.bar(figsize=(10,6));

# %%
results.set_index('year_test').loc[: , ['expected_return', 'real_return']].add(1).cumprod(axis=0).sub(1).plot(figsize=(10,6));

# %%
data2 = calc_markowitz(lreturns['2011':'2013'], verbose=False)
w = data2['weights']
del data2['weights']
future = lreturns['2014':'2014'].add(1).cumprod(axis=0).sub(1);

future.plot(figsize=(20,5));

# %%
weighted_future = future * pd.Series(w)
weighted_future.plot(figsize=(20,5));

# %%
total = weighted_future.sum(axis=1).rename('Portfolio')
total.plot(figsize=(20,5));

# %%
total.describe()
#S = risk_models.sample_cov(total, returns_data=True).sum()
# Out:
# count    261.000000
# mean       0.032249
# std        0.041161
# min       -0.043853
# 25%       -0.005817
# 50%        0.032239
# 75%        0.076001
# max        0.096955
# Name: Portfolio, dtype: float64

# %%
total.iloc[-1]
# Out:
# 0.09235451089192259
